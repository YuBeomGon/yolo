# %%
# imports
import matplotlib.pyplot as plt
import matplotlib
# import joblib
import cv2
import os
import torch 
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import random
import math
import sys
sys.path.append('../')

#import pretrainedmodels
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

from gated import *
from resnet import resnet18
from resnet_gated import resnet18_gated
from train import train_sgd, test, train_gated
from dataset import *
# Out:
# [0.05, 0.04351133533380851, 0.03763019350290237, 0.03233860639039575, 0.027610188407766852, 0.023412708106044778, 0.019710173577058045, 0.01646450246756338, 0.013636839516207507, 0.011188577139226377, 0.00908212776868068, 0.0072814904000044894, 0.005752648131336976, 0.004463828361377955, 0.003385652732557608, 0.0024911998332304472, 0.0017560000734507363, 0.001157978988356383, 0.0006773624649329806, 0.00029655499559261365]

# %%
# !pip install pretrainedmodels

# %%
# device = torch.device("cpu")
device = torch.device("cuda")
dtype = torch.float
BATCH_SIZE = 64

# %%
image_paths = list(paths.list_images('../data/101_ObjectCategories'))
data = []
labels = []
for image_path in image_paths:
    label = image_path.split(os.path.sep)[-2]
    if label == 'BACKGROUND_Google':
        continue
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    data.append(image)
    labels.append(label)
data = np.array(data)
labels = np.array(labels)
# Out:
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':

# %%
len(set(labels))
# Out:
# 101

# %%
# one hot encode
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
print(f"Total number of classes: {len(lb.classes_)}")
# Out:
# Total number of classes: 101

# %%
# divide the data into train, validation, and test set
(x_train, x_val , y_train, y_val) = train_test_split(data, labels, 
                                                    test_size=0.3,  
                                                    stratify=labels,
                                                    random_state=42)

(x_val, x_test, y_val, y_test) = train_test_split(x_val, y_val, 
                                                    test_size=0.65, 
                                                    random_state=42)
print(f"x_train examples: {x_train.shape}\nx_test examples: {x_test.shape}\nx_val examples: {x_val.shape}")
# Out:
# x_train examples: (6073,)
# x_test examples: (1693,)
# x_val examples: (911,)

# %%
np.argmax(y_val[:20], axis=-1)
# Out:
# array([98,  3, 65, 52,  0,  1, 71, 72,  3,  3, 23,  3,  1, 55,  1, 11, 17,
#        40, 90, 53])

# %%
train_data = ImageDataset(x_train, y_train, train_transform)
val_data = ImageDataset(x_val, y_val, val_transform)
test_data = ImageDataset(x_test, y_test, val_transform)

# dataloaders
trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
valloader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True)
testloader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
model = resnet18(pretrained=False).to(device)
model_gated = resnet18_gated(pretrained=False).to(device)
# Out:
# dilation [False, False, False]
# stride 1
# downsample
# stride 2
# downsample
# stride 2
# downsample
# stride 2
# dilation [False, False, False]
# stride 1
# downsample
# stride 2
# downsample
# stride 2
# downsample
# stride 2

# %%
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
train_sgd(model, trainloader, valloader)
# Out:
# Training on 6073 examples, validating on 911 examples...
# Epoch 1 of 20
# Train Loss: 0.0647, Train Acc: 17.95
# Val Loss: 0.0591, Val Acc: 24.37
# Epoch 2 of 20
# Train Loss: 0.0509, Train Acc: 29.06
# Val Loss: 0.0507, Val Acc: 35.13
# Epoch 3 of 20
# Train Loss: 0.0453, Train Acc: 35.25
# Val Loss: 0.0459, Val Acc: 38.20
# Epoch 4 of 20
# Train Loss: 0.0401, Train Acc: 41.36
# Val Loss: 0.0398, Val Acc: 44.13
# Epoch 5 of 20
# Train Loss: 0.0349, Train Acc: 47.06
# Val Loss: 0.0370, Val Acc: 47.75
# Epoch 6 of 20
# Train Loss: 0.0304, Train Acc: 53.35
# Val Loss: 0.0336, Val Acc: 51.48
# Epoch 7 of 20
# Train Loss: 0.0262, Train Acc: 58.47
# Val Loss: 0.0306, Val Acc: 55.54
# Epoch 8 of 20
# Train Loss: 0.0223, Train Acc: 64.33
# Val Loss: 0.0290, Val Acc: 58.95
# Epoch 9 of 20
# Train Loss: 0.0187, Train Acc: 68.85
# Val Loss: 0.0266, Val Acc: 59.93
# Epoch 10 of 20
# Train Loss: 0.0158, Train Acc: 73.77
# Val Loss: 0.0255, Val Acc: 60.92
# Epoch 11 of 20
# Train Loss: 0.0130, Train Acc: 79.57
# Val Loss: 0.0238, Val Acc: 63.45
# Epoch 12 of 20
# Train Loss: 0.0104, Train Acc: 84.37
# Val Loss: 0.0241, Val Acc: 64.98
# Epoch 13 of 20
# Train Loss: 0.0082, Train Acc: 88.79
# Val Loss: 0.0230, Val Acc: 64.98
# Epoch 14 of 20
# Train Loss: 0.0067, Train Acc: 91.96
# Val Loss: 0.0225, Val Acc: 65.86
# Epoch 15 of 20
# Train Loss: 0.0054, Train Acc: 94.17
# Val Loss: 0.0224, Val Acc: 66.63
# Epoch 16 of 20
# Train Loss: 0.0044, Train Acc: 96.06
# Val Loss: 0.0223, Val Acc: 65.97
# Epoch 17 of 20
# Train Loss: 0.0038, Train Acc: 97.35
# Val Loss: 0.0217, Val Acc: 66.85
# Epoch 18 of 20
# Train Loss: 0.0032, Train Acc: 97.96
# Val Loss: 0.0224, Val Acc: 66.96
# Epoch 19 of 20
# Train Loss: 0.0029, Train Acc: 98.50
# Val Loss: 0.0213, Val Acc: 66.63
# Epoch 20 of 20
# Train Loss: 0.0026, Train Acc: 99.01
# Val Loss: 0.0216, Val Acc: 65.97
# 3.419409743944804 minutes

# %%
correct, total = test(model, testloader)
print('Accuracy of testthe network on test images: %0.3f %%' % (100 * correct / total))
print('train.py finished running')
# Out:
# Accuracy of testthe network on test images: 68.340 %
# train.py finished running

# %%
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
train_gated(model_gated, trainloader, valloader)
# Out:
# Training on 6073 examples, validating on 911 examples...
# Epoch 1 of 20
# Train Loss: 0.0696, Train Acc: 17.50
# Val Loss: 0.0660, Val Acc: 21.73
# Epoch 2 of 20
# Train Loss: 0.0490, Train Acc: 31.63
# Val Loss: 0.0515, Val Acc: 35.13
# Epoch 3 of 20
# Train Loss: 0.0424, Train Acc: 38.68
# Val Loss: 0.0460, Val Acc: 39.30
# Epoch 4 of 20
# Train Loss: 0.0376, Train Acc: 44.44
# Val Loss: 0.0420, Val Acc: 41.71
# Epoch 5 of 20
# Train Loss: 0.0339, Train Acc: 48.89
# Val Loss: 0.0375, Val Acc: 46.43
# Epoch 6 of 20
# Train Loss: 0.0302, Train Acc: 53.55
# Val Loss: 0.0348, Val Acc: 51.59
# Epoch 7 of 20
# Train Loss: 0.0277, Train Acc: 57.04
# Val Loss: 1.8235, Val Acc: 49.29
# Epoch 8 of 20
# Train Loss: 0.0252, Train Acc: 60.33
# Val Loss: 0.0316, Val Acc: 53.24
# Epoch 9 of 20
# Train Loss: 0.0226, Train Acc: 63.36
# Val Loss: 0.0309, Val Acc: 54.88
# Epoch 10 of 20
# Train Loss: 0.0206, Train Acc: 66.80
# Val Loss: 0.0294, Val Acc: 55.87
# Epoch 11 of 20
# Train Loss: 0.0187, Train Acc: 70.38
# Val Loss: 0.0286, Val Acc: 56.97
# Epoch 12 of 20
# Train Loss: 0.0169, Train Acc: 72.86
# Val Loss: 0.0291, Val Acc: 57.52
# Epoch 13 of 20
# Train Loss: 0.0155, Train Acc: 75.48
# Val Loss: 0.0290, Val Acc: 57.63
# Epoch 14 of 20
# Train Loss: 0.0141, Train Acc: 78.07
# Val Loss: 0.0290, Val Acc: 58.18
# Epoch 15 of 20
# Train Loss: 0.0131, Train Acc: 79.37
# Val Loss: 0.0284, Val Acc: 58.84
# Epoch 16 of 20
# Train Loss: 0.0123, Train Acc: 81.24
# Val Loss: 0.0286, Val Acc: 58.29
# Epoch 17 of 20
# Train Loss: 0.0115, Train Acc: 82.89
# Val Loss: 0.0277, Val Acc: 58.51
# Epoch 18 of 20
# Train Loss: 0.0108, Train Acc: 84.31
# Val Loss: 0.0292, Val Acc: 58.29
# Epoch 19 of 20
# Train Loss: 0.0104, Train Acc: 85.66
# Val Loss: 0.0277, Val Acc: 59.06
# Epoch 20 of 20
# Train Loss: 0.0098, Train Acc: 86.60
# Val Loss: 0.0289, Val Acc: 58.40
# 17.779368563493094 minutes

# %%
correct, total = test(model_gated, testloader)
print('Accuracy of testthe network on test images: %0.3f %%' % (100 * correct / total))
print('train.py finished running')
# Out:
# Accuracy of testthe network on test images: 59.185 %
# train.py finished running
