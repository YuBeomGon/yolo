# %%
# imports
import matplotlib.pyplot as plt
import matplotlib
# import joblib
import cv2
import os
import torch 
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import random
import math
import sys
sys.path.append('../../')

#import pretrainedmodels
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm


from resnet import *
from train import train, test
from dataset import *
from batchnorm import BatchNorm, CustomBatchNorm2d

# %%
# !pip install pretrainedmodels

# %%
#device = torch.device("cpu")
device = torch.device("cuda")
dtype = torch.float

BATCH_SIZE = 64

# %%
image_paths = list(paths.list_images('../../data/101_ObjectCategories'))
data = []
labels = []
for image_path in image_paths:
    label = image_path.split(os.path.sep)[-2]
    if label == 'BACKGROUND_Google':
        continue
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    data.append(image)
    labels.append(label)
data = np.array(data)
labels = np.array(labels)
# Out:
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':

# %%
len(set(labels))
# Out:
# 101

# %%
# one hot encode
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
print(f"Total number of classes: {len(lb.classes_)}")
# Out:
# Total number of classes: 101

# %%
# divide the data into train, validation, and test set
(x_train, x_val , y_train, y_val) = train_test_split(data, labels, 
                                                    test_size=0.3,  
                                                    stratify=labels,
                                                    random_state=42)

(x_val, x_test, y_val, y_test) = train_test_split(x_val, y_val, 
                                                    test_size=0.65, 
                                                    random_state=42)
print(f"x_train examples: {x_train.shape}\nx_test examples: {x_test.shape}\nx_val examples: {x_val.shape}")
# Out:
# x_train examples: (6073,)
# x_test examples: (1693,)
# x_val examples: (911,)

# %%
np.argmax(y_val[:20], axis=-1)
# Out:
# array([98,  3, 65, 52,  0,  1, 71, 72,  3,  3, 23,  3,  1, 55,  1, 11, 17,
#        40, 90, 53])

# %%
train_data = ImageDataset(x_train, y_train, train_transform)
val_data = ImageDataset(x_val, y_val, val_transform)
test_data = ImageDataset(x_test, y_test, val_transform)

# dataloaders
trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
valloader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True)
testloader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
# model.eval()

# %%
# resnet18
# model = resnet18(pretrained=False, norm_layer=BatchNorm).to(device)

# %%
# print('customized batchnorm test')
# print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
# model = resnet18(pretrained=False, norm_layer=BatchNorm).to(device)
# train(model, trainloader, valloader)
# correct, total = test(model, testloader)
# print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))

# %%
print('customized batchnorm test')
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
model = resnet18(pretrained=False, norm_layer=CustomBatchNorm2d).to(device)
train(model, trainloader, valloader)
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# customized batchnorm test
# Training on 6073 examples, validating on 911 examples...
# norm layer <class 'batchnorm.CustomBatchNorm2d'>
# dilation [False, False, False]
# stride 1
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch 1 of 32
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# train loss 0.0585 val loss 0.0621 train acc 22.84 val acc 27.44 lr 0.0010
# Epoch 2 of 32
# train loss 0.0504 val loss 0.0597 train acc 29.87 val acc 30.41 lr 0.0010
# Epoch 3 of 32
# train loss 0.0461 val loss 0.0496 train acc 34.93 val acc 35.89 lr 0.0010
# Epoch 4 of 32
# train loss 0.0427 val loss 0.0446 train acc 38.76 val acc 39.41 lr 0.0010
# Epoch 5 of 32
# train loss 0.0397 val loss 0.0413 train acc 41.35 val acc 42.92 lr 0.0010
# Epoch 6 of 32
# train loss 0.0364 val loss 0.0401 train acc 45.33 val acc 42.81 lr 0.0010
# Epoch 7 of 32
# train loss 0.0332 val loss 0.0406 train acc 49.20 val acc 43.03 lr 0.0010
# Epoch 8 of 32
# train loss 0.0307 val loss 0.0334 train acc 52.40 val acc 51.70 lr 0.0010
# Epoch 9 of 32
# train loss 0.0281 val loss 0.0333 train acc 55.34 val acc 49.84 lr 0.0010
# Epoch 10 of 32
# train loss 0.0253 val loss 0.0320 train acc 59.79 val acc 48.96 lr 0.0010
# Epoch 11 of 32
# train loss 0.0233 val loss 0.0310 train acc 61.73 val acc 54.23 lr 0.0010
# Epoch 12 of 32
# train loss 0.0209 val loss 0.0332 train acc 65.85 val acc 53.46 lr 0.0010
# Epoch 13 of 32
# train loss 0.0187 val loss 0.0280 train acc 68.70 val acc 56.31 lr 0.0010
# Epoch 14 of 32
# train loss 0.0174 val loss 0.0305 train acc 70.43 val acc 56.97 lr 0.0010
# Epoch 15 of 32
# train loss 0.0154 val loss 0.0262 train acc 73.80 val acc 61.47 lr 0.0010
# Epoch 16 of 32
# train loss 0.0141 val loss 0.0256 train acc 75.33 val acc 61.47 lr 0.0010
# Epoch 17 of 32
# train loss 0.0118 val loss 0.0251 train acc 79.07 val acc 63.67 lr 0.0010
# Epoch 18 of 32
# train loss 0.0106 val loss 0.0262 train acc 80.85 val acc 62.90 lr 0.0010
# Epoch 19 of 32
# train loss 0.0091 val loss 0.0246 train acc 83.52 val acc 65.53 lr 0.0010
# Epoch 20 of 32
# train loss 0.0078 val loss 0.0249 train acc 86.45 val acc 66.41 lr 0.0010
# Epoch 21 of 32
# train loss 0.0062 val loss 0.0264 train acc 88.75 val acc 65.97 lr 0.0010
# Epoch 22 of 32
# train loss 0.0050 val loss 0.0277 train acc 91.06 val acc 65.97 lr 0.0010
# Epoch 23 of 32
# train loss 0.0044 val loss 0.0275 train acc 92.01 val acc 67.62 lr 0.0010
# Epoch 24 of 32
# train loss 0.0033 val loss 0.0246 train acc 94.32 val acc 67.07 lr 0.0010
# Epoch 25 of 32
# train loss 0.0029 val loss 0.0264 train acc 94.66 val acc 65.64 lr 0.0010
# Epoch 26 of 32
# train loss 0.0021 val loss 0.0251 train acc 96.43 val acc 69.92 lr 0.0010
# Epoch 27 of 32
# train loss 0.0015 val loss 0.0267 train acc 97.96 val acc 68.39 lr 0.0010
# Epoch 28 of 32
# train loss 0.0012 val loss 0.0250 train acc 98.57 val acc 70.25 lr 0.0010
# Epoch 29 of 32
# train loss 0.0014 val loss 0.0278 train acc 97.84 val acc 69.05 lr 0.0010
# Epoch 30 of 32
# train loss 0.0017 val loss 0.0317 train acc 97.18 val acc 65.86 lr 0.0010
# Epoch 31 of 32
# train loss 0.0013 val loss 0.0288 train acc 97.93 val acc 67.73 lr 0.0010
# Epoch 32 of 32
# train loss 0.0015 val loss 0.0320 train acc 97.46 val acc 66.52 lr 0.0010
# 20.462030831972758 minutes
# Accuracy of the network on test images: 66.214 %

# %%
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
model = resnet18(pretrained=False).to(device)
train(model, trainloader, valloader)
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# Training on 6073 examples, validating on 911 examples...
# norm layer <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# dilation [False, False, False]
# stride 1
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch 1 of 32
# train loss 0.0571 val loss 0.0611 train acc 23.89 val acc 23.60 lr 0.0010
# Epoch 2 of 32
# train loss 0.0503 val loss 0.0551 train acc 29.95 val acc 30.85 lr 0.0010
# Epoch 3 of 32
# train loss 0.0467 val loss 0.0557 train acc 34.27 val acc 27.77 lr 0.0010
# Epoch 4 of 32
# train loss 0.0435 val loss 0.0448 train acc 37.46 val acc 38.97 lr 0.0010
# Epoch 5 of 32
# train loss 0.0399 val loss 0.0464 train acc 41.22 val acc 38.42 lr 0.0010
# Epoch 6 of 32
# train loss 0.0373 val loss 0.0418 train acc 44.31 val acc 42.15 lr 0.0010
# Epoch 7 of 32
# train loss 0.0342 val loss 0.0394 train acc 48.58 val acc 46.21 lr 0.0010
# Epoch 8 of 32
# train loss 0.0316 val loss 0.0381 train acc 51.19 val acc 46.76 lr 0.0010
# Epoch 9 of 32
# train loss 0.0294 val loss 0.0345 train acc 54.50 val acc 51.37 lr 0.0010
# Epoch 10 of 32
# train loss 0.0264 val loss 0.0346 train acc 57.53 val acc 51.04 lr 0.0010
# Epoch 11 of 32
# train loss 0.0242 val loss 0.0312 train acc 60.50 val acc 54.77 lr 0.0010
# Epoch 12 of 32
# train loss 0.0219 val loss 0.0293 train acc 64.93 val acc 56.42 lr 0.0010
# Epoch 13 of 32
# train loss 0.0199 val loss 0.0324 train acc 66.92 val acc 54.99 lr 0.0010
# Epoch 14 of 32
# train loss 0.0181 val loss 0.0326 train acc 69.69 val acc 56.09 lr 0.0010
# Epoch 15 of 32
# train loss 0.0160 val loss 0.0273 train acc 72.53 val acc 62.24 lr 0.0010
# Epoch 16 of 32
# train loss 0.0147 val loss 0.0261 train acc 74.44 val acc 63.67 lr 0.0010
# Epoch 17 of 32
# train loss 0.0130 val loss 0.0271 train acc 77.31 val acc 62.13 lr 0.0010
# Epoch 18 of 32
# train loss 0.0112 val loss 0.0300 train acc 80.44 val acc 59.39 lr 0.0010
# Epoch 19 of 32
# train loss 0.0097 val loss 0.0280 train acc 82.91 val acc 62.90 lr 0.0010
# Epoch 20 of 32
# train loss 0.0084 val loss 0.0255 train acc 84.83 val acc 66.52 lr 0.0010
# Epoch 21 of 32
# train loss 0.0072 val loss 0.0239 train acc 87.12 val acc 67.73 lr 0.0010
# Epoch 22 of 32
# train loss 0.0062 val loss 0.0261 train acc 88.74 val acc 65.42 lr 0.0010
# Epoch 23 of 32
# train loss 0.0054 val loss 0.0344 train acc 89.91 val acc 61.14 lr 0.0010
# Epoch 24 of 32
# train loss 0.0040 val loss 0.0269 train acc 92.89 val acc 65.31 lr 0.0010
# Epoch 25 of 32
# train loss 0.0034 val loss 0.0252 train acc 93.94 val acc 68.28 lr 0.0010
# Epoch 26 of 32
# train loss 0.0025 val loss 0.0302 train acc 95.60 val acc 66.30 lr 0.0010
# Epoch 27 of 32
# train loss 0.0022 val loss 0.0261 train acc 96.51 val acc 68.17 lr 0.0010
# Epoch 28 of 32
# train loss 0.0019 val loss 0.0297 train acc 96.92 val acc 67.18 lr 0.0010
# Epoch 29 of 32
# train loss 0.0023 val loss 0.0266 train acc 95.77 val acc 68.61 lr 0.0010
# Epoch 30 of 32
# train loss 0.0014 val loss 0.0279 train acc 97.97 val acc 67.51 lr 0.0010
# Epoch 31 of 32
# train loss 0.0009 val loss 0.0257 train acc 98.63 val acc 70.58 lr 0.0010
# Epoch 32 of 32
# train loss 0.0004 val loss 0.0238 train acc 99.84 val acc 72.78 lr 0.0010
# 5.320549949010213 minutes
# Accuracy of the network on test images: 73.774 %
