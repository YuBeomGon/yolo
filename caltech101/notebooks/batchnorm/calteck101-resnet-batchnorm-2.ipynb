# %%
# imports
import matplotlib.pyplot as plt
import matplotlib
# import joblib
import cv2
import os
import torch 
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import random
import math
import sys
sys.path.append('../../')

#import pretrainedmodels
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

from resnet import *
from train import train, test
from dataset import *
from batchnorm import BatchNorm, CustomBatchNorm2d

# %%
# !pip install pretrainedmodels

# %%
#device = torch.device("cpu")
device = torch.device("cuda")
dtype = torch.float

BATCH_SIZE = 64

# %%
image_paths = list(paths.list_images('../../data/101_ObjectCategories'))
data = []
labels = []
for image_path in image_paths:
    label = image_path.split(os.path.sep)[-2]
    if label == 'BACKGROUND_Google':
        continue
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    data.append(image)
    labels.append(label)
data = np.array(data)
labels = np.array(labels)
# Out:
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':

# %%
len(set(labels))
# Out:
# 101

# %%
# one hot encode
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
print(f"Total number of classes: {len(lb.classes_)}")
# Out:
# Total number of classes: 101

# %%
# divide the data into train, validation, and test set
(x_train, x_val , y_train, y_val) = train_test_split(data, labels, 
                                                    test_size=0.3,  
                                                    stratify=labels,
                                                    random_state=42)

(x_val, x_test, y_val, y_test) = train_test_split(x_val, y_val, 
                                                    test_size=0.65, 
                                                    random_state=42)
print(f"x_train examples: {x_train.shape}\nx_test examples: {x_test.shape}\nx_val examples: {x_val.shape}")
# Out:
# x_train examples: (6073,)
# x_test examples: (1693,)
# x_val examples: (911,)

# %%
np.argmax(y_val[:20], axis=-1)
# Out:
# array([98,  3, 65, 52,  0,  1, 71, 72,  3,  3, 23,  3,  1, 55,  1, 11, 17,
#        40, 90, 53])

# %%
train_data = ImageDataset(x_train, y_train, train_transform)
val_data = ImageDataset(x_val, y_val, val_transform)
test_data = ImageDataset(x_test, y_test, val_transform)

# dataloaders
trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=12)
valloader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=12)
testloader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False, num_workers=12)

# %%
# model.eval()

# %%
# resnet18
# model = resnet18(pretrained=False, norm_layer=BatchNorm).to(device)

# %%
# print('customized batchnorm test')
# print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
# model = resnet18(pretrained=False, norm_layer=BatchNorm).to(device)
# train(model, trainloader, valloader)
# correct, total = test(model, testloader)
# print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))

# %%
model = resnet18(pretrained=False)
initial_state = model.state_dict()
# for i in  initial_state :
#     if 'bn' in i :
#         print(initial_state[i])
# Out:
# norm layer <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# dilation [False, False, False]
# stride 1
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()

# %%
# initial_state

# %%
# model = resnet18(pretrained=False, norm_layer=CustomBatchNorm2d).to(device)
# initial_state = model.state_dict()
# for i in  initial_state :
#     if 'bn' in i :
#         print(initial_state[i])

# %%
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
model = resnet18(pretrained=False)
model.load_state_dict(initial_state)
model.to(device)
train(model, trainloader, valloader, opt='sgd')
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# Training on 6073 examples, validating on 911 examples...
# norm layer <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# dilation [False, False, False]
# stride 1
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0001
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0.0001
# )
# Epoch 1 of 32
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# train loss 0.0698 val loss 0.0566 train acc 18.36 val acc 26.34 lr 0.1000
# Epoch 2 of 32
# train loss 0.0497 val loss 0.0599 train acc 30.96 val acc 28.54 lr 0.1000
# Epoch 3 of 32
# train loss 0.0453 val loss 0.0472 train acc 36.18 val acc 38.86 lr 0.1000
# Epoch 4 of 32
# train loss 0.0408 val loss 0.0441 train acc 41.33 val acc 39.19 lr 0.1000
# Epoch 5 of 32
# train loss 0.0375 val loss 0.0395 train acc 44.74 val acc 45.12 lr 0.1000
# Epoch 6 of 32
# train loss 0.0343 val loss 0.0420 train acc 48.89 val acc 43.91 lr 0.1000
# Epoch 7 of 32
# train loss 0.0322 val loss 0.0377 train acc 50.72 val acc 47.64 lr 0.1000
# Epoch 8 of 32
# train loss 0.0293 val loss 0.0349 train acc 54.14 val acc 50.16 lr 0.1000
# Epoch 9 of 32
# train loss 0.0227 val loss 0.0292 train acc 64.02 val acc 57.85 lr 0.0100
# Epoch 10 of 32
# train loss 0.0205 val loss 0.0281 train acc 66.90 val acc 59.06 lr 0.0100
# Epoch 11 of 32
# train loss 0.0195 val loss 0.0283 train acc 68.85 val acc 59.39 lr 0.0100
# Epoch 12 of 32
# train loss 0.0186 val loss 0.0274 train acc 70.01 val acc 59.71 lr 0.0100
# Epoch 13 of 32
# train loss 0.0178 val loss 0.0273 train acc 71.18 val acc 60.70 lr 0.0100
# Epoch 14 of 32
# train loss 0.0170 val loss 0.0273 train acc 72.09 val acc 60.26 lr 0.0100
# Epoch 15 of 32
# train loss 0.0161 val loss 0.0272 train acc 73.39 val acc 60.70 lr 0.0100
# Epoch 16 of 32
# train loss 0.0154 val loss 0.0265 train acc 74.02 val acc 60.70 lr 0.0100
# Epoch 17 of 32
# train loss 0.0138 val loss 0.0257 train acc 76.98 val acc 62.35 lr 0.0010
# Epoch 18 of 32
# train loss 0.0134 val loss 0.0262 train acc 78.05 val acc 62.79 lr 0.0010
# Epoch 19 of 32
# train loss 0.0132 val loss 0.0257 train acc 78.18 val acc 63.01 lr 0.0010
# Epoch 20 of 32
# train loss 0.0131 val loss 0.0267 train acc 78.35 val acc 62.90 lr 0.0010
# Epoch 21 of 32
# train loss 0.0129 val loss 0.0259 train acc 78.64 val acc 62.79 lr 0.0010
# Epoch 22 of 32
# train loss 0.0129 val loss 0.0251 train acc 79.10 val acc 62.68 lr 0.0010
# Epoch 23 of 32
# train loss 0.0127 val loss 0.0259 train acc 79.30 val acc 62.68 lr 0.0010
# Epoch 24 of 32
# train loss 0.0127 val loss 0.0262 train acc 78.81 val acc 62.68 lr 0.0010
# Epoch 25 of 32
# train loss 0.0123 val loss 0.0256 train acc 80.01 val acc 62.90 lr 0.0001
# Epoch 26 of 32
# train loss 0.0124 val loss 0.0261 train acc 79.37 val acc 62.79 lr 0.0001
# Epoch 27 of 32
# train loss 0.0123 val loss 0.0260 train acc 79.65 val acc 62.68 lr 0.0001
# Epoch 28 of 32
# train loss 0.0123 val loss 0.0259 train acc 79.94 val acc 63.34 lr 0.0001
# Epoch 29 of 32
# train loss 0.0124 val loss 0.0254 train acc 79.55 val acc 63.45 lr 0.0001
# Epoch 30 of 32
# train loss 0.0123 val loss 0.0259 train acc 79.71 val acc 63.01 lr 0.0001
# Epoch 31 of 32
# train loss 0.0124 val loss 0.0253 train acc 79.76 val acc 63.12 lr 0.0001
# Epoch 32 of 32
# train loss 0.0123 val loss 0.0268 train acc 79.91 val acc 62.68 lr 0.0001
# 5.320188796520233 minutes
# Accuracy of the network on test images: 64.383 %

# %%
print('customized batchnorm test')
print(f"Training on {len(train_data)} examples, validating on {len(val_data)} examples...")
model = resnet18(pretrained=False, norm_layer=CustomBatchNorm2d)
model.load_state_dict(initial_state)
model.to(device)
train(model, trainloader, valloader, opt='sgd')
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# customized batchnorm test
# Training on 6073 examples, validating on 911 examples...
# norm layer <class 'batchnorm.CustomBatchNorm2d'>
# dilation [False, False, False]
# stride 1
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# downsample
# stride 2
# baskicblock ReLU()
# baskicblock ReLU()
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0001
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0.0001
# )
# Epoch 1 of 32
# train loss 0.0731 val loss 0.0850 train acc 17.14 val acc 19.43 lr 0.1000
# Epoch 2 of 32
# train loss 0.0527 val loss 0.0551 train acc 29.15 val acc 30.30 lr 0.1000
# Epoch 3 of 32
# train loss 0.0479 val loss 0.0483 train acc 33.74 val acc 35.13 lr 0.1000
# Epoch 4 of 32
# train loss 0.0440 val loss 0.0462 train acc 37.56 val acc 38.86 lr 0.1000
# Epoch 5 of 32
# train loss 0.0408 val loss 0.0452 train acc 40.94 val acc 41.16 lr 0.1000
# Epoch 6 of 32
# train loss 0.0371 val loss 0.0416 train acc 44.61 val acc 43.14 lr 0.1000
# Epoch 7 of 32
# train loss 0.0345 val loss 0.0367 train acc 47.69 val acc 49.62 lr 0.1000
# Epoch 8 of 32
# train loss 0.0318 val loss 0.0354 train acc 50.85 val acc 49.18 lr 0.1000
# Epoch 9 of 32
# train loss 0.0251 val loss 0.0299 train acc 60.76 val acc 57.08 lr 0.0100
# Epoch 10 of 32
# train loss 0.0230 val loss 0.0297 train acc 63.26 val acc 56.86 lr 0.0100
# Epoch 11 of 32
# train loss 0.0220 val loss 0.0281 train acc 64.33 val acc 58.18 lr 0.0100
# Epoch 12 of 32
# train loss 0.0210 val loss 0.0276 train acc 65.80 val acc 58.51 lr 0.0100
# Epoch 13 of 32
# train loss 0.0202 val loss 0.0275 train acc 66.69 val acc 58.73 lr 0.0100
# Epoch 14 of 32
# train loss 0.0193 val loss 0.0275 train acc 68.12 val acc 59.39 lr 0.0100
# Epoch 15 of 32
# train loss 0.0187 val loss 0.0267 train acc 69.36 val acc 58.62 lr 0.0100
# Epoch 16 of 32
# train loss 0.0178 val loss 0.0271 train acc 70.57 val acc 59.60 lr 0.0100
# Epoch 17 of 32
# train loss 0.0161 val loss 0.0266 train acc 73.16 val acc 60.37 lr 0.0010
# Epoch 18 of 32
# train loss 0.0157 val loss 0.0265 train acc 74.18 val acc 61.14 lr 0.0010
# Epoch 19 of 32
# train loss 0.0156 val loss 0.0262 train acc 74.36 val acc 60.81 lr 0.0010
# Epoch 20 of 32
# train loss 0.0156 val loss 0.0254 train acc 74.49 val acc 61.36 lr 0.0010
# Epoch 21 of 32
# train loss 0.0152 val loss 0.0258 train acc 74.77 val acc 61.03 lr 0.0010
# Epoch 22 of 32
# train loss 0.0153 val loss 0.0262 train acc 74.48 val acc 61.58 lr 0.0010
# Epoch 23 of 32
# train loss 0.0151 val loss 0.0260 train acc 75.25 val acc 61.80 lr 0.0010
# Epoch 24 of 32
# train loss 0.0149 val loss 0.0255 train acc 76.07 val acc 61.47 lr 0.0010
# Epoch 25 of 32
# train loss 0.0148 val loss 0.0257 train acc 75.23 val acc 61.91 lr 0.0001
# Epoch 26 of 32
# train loss 0.0148 val loss 0.0259 train acc 75.71 val acc 62.13 lr 0.0001
# Epoch 27 of 32
# train loss 0.0146 val loss 0.0258 train acc 76.26 val acc 61.47 lr 0.0001
# Epoch 28 of 32
# train loss 0.0147 val loss 0.0255 train acc 75.56 val acc 61.58 lr 0.0001
# Epoch 29 of 32
# train loss 0.0148 val loss 0.0255 train acc 75.15 val acc 61.91 lr 0.0001
# Epoch 30 of 32
# train loss 0.0146 val loss 0.0254 train acc 75.78 val acc 61.80 lr 0.0001
# Epoch 31 of 32
# train loss 0.0146 val loss 0.0255 train acc 75.86 val acc 61.91 lr 0.0001
# Epoch 32 of 32
# train loss 0.0147 val loss 0.0257 train acc 75.75 val acc 61.80 lr 0.0001
# 24.380986976623536 minutes
# Accuracy of the network on test images: 62.256 %
