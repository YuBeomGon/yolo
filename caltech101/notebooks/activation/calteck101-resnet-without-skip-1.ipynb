# %%
# imports
import matplotlib.pyplot as plt
import matplotlib
# import joblib
import cv2
import os
import torch 
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import random
import math
import sys
sys.path.append('../../')

#import pretrainedmodels
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm

from gated import *
# from resnet_gated_without_skip import *
# from resnet_gated import *
from resnet import *
from train import train, test
from dataset import *

# %%
# !pip install pretrainedmodels

# %%
#device = torch.device("cpu")
device = torch.device("cuda")
dtype = torch.float

BATCH_SIZE = 64

# %%
image_paths = list(paths.list_images('../../data/101_ObjectCategories'))
data = []
labels = []
for image_path in image_paths:
    label = image_path.split(os.path.sep)[-2]
    if label == 'BACKGROUND_Google':
        continue
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    data.append(image)
    labels.append(label)
data = np.array(data)
labels = np.array(labels)
# Out:
# /home/beomgon/anaconda3/envs/pytorch_retina/lib/python3.7/site-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':

# %%
len(set(labels))
# Out:
# 101

# %%
# one hot encode
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
print(f"Total number of classes: {len(lb.classes_)}")
# Out:
# Total number of classes: 101

# %%
# divide the data into train, validation, and test set
(x_train, x_val , y_train, y_val) = train_test_split(data, labels, 
                                                    test_size=0.3,  
                                                    stratify=labels,
                                                    random_state=42)

(x_val, x_test, y_val, y_test) = train_test_split(x_val, y_val, 
                                                    test_size=0.65, 
                                                    random_state=42)
print(f"x_train examples: {x_train.shape}\nx_test examples: {x_test.shape}\nx_val examples: {x_val.shape}")
# Out:
# x_train examples: (6073,)
# x_test examples: (1693,)
# x_val examples: (911,)

# %%
np.argmax(y_val[:20], axis=-1)
# Out:
# array([98,  3, 65, 52,  0,  1, 71, 72,  3,  3, 23,  3,  1, 55,  1, 11, 17,
#        40, 90, 53])

# %%
train_data = ImageDataset(x_train, y_train, train_transform)
val_data = ImageDataset(x_val, y_val, val_transform)
test_data = ImageDataset(x_test, y_test, val_transform)

# dataloaders
trainloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
valloader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True)
testloader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
# model.eval()

# %%
model = resnet18(pretrained=False, activation='relu').to(device)
train(model, trainloader, valloader)
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# dilation [False, False, False]
# stride 1
# ReLU()
# ReLU()
# downsample
# stride 2
# ReLU()
# ReLU()
# downsample
# stride 2
# ReLU()
# ReLU()
# downsample
# stride 2
# ReLU()
# ReLU()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Epoch 1 of 25
# Train Loss: 0.0565, Train Acc: 23.83
# Val Loss: 0.0577, Val Acc: 27.99
# Epoch 2 of 25
# Train Loss: 0.0493, Train Acc: 30.59
# Val Loss: 0.0524, Val Acc: 29.86
# Epoch 3 of 25
# Train Loss: 0.0437, Train Acc: 37.41
# Val Loss: 0.0485, Val Acc: 37.65
# Epoch 4 of 25
# Train Loss: 0.0385, Train Acc: 42.83
# Val Loss: 0.0415, Val Acc: 43.25
# Epoch 5 of 25
# Train Loss: 0.0341, Train Acc: 48.23
# Val Loss: 0.0340, Val Acc: 49.62
# Epoch 6 of 25
# Train Loss: 0.0290, Train Acc: 54.82
# Val Loss: 0.0351, Val Acc: 48.52
# Epoch 7 of 25
# Train Loss: 0.0252, Train Acc: 59.56
# Val Loss: 0.0305, Val Acc: 53.02
# Epoch 8 of 25
# Train Loss: 0.0212, Train Acc: 65.16
# Val Loss: 0.0275, Val Acc: 57.19
# Epoch 9 of 25
# Train Loss: 0.0176, Train Acc: 71.25
# Val Loss: 0.0264, Val Acc: 61.03
# Epoch 10 of 25
# Train Loss: 0.0143, Train Acc: 76.29
# Val Loss: 0.0249, Val Acc: 61.80
# Epoch 11 of 25
# Train Loss: 0.0113, Train Acc: 81.48
# Val Loss: 0.0224, Val Acc: 65.42
# Epoch 12 of 25
# Train Loss: 0.0088, Train Acc: 85.39
# Val Loss: 0.0222, Val Acc: 67.51
# Epoch 13 of 25
# Train Loss: 0.0062, Train Acc: 90.93
# Val Loss: 0.0221, Val Acc: 67.40
# Epoch 14 of 25
# Train Loss: 0.0044, Train Acc: 93.56
# Val Loss: 0.0241, Val Acc: 66.74
# Epoch 15 of 25
# Train Loss: 0.0030, Train Acc: 96.20
# Val Loss: 0.0220, Val Acc: 69.48
# Epoch 16 of 25
# Train Loss: 0.0018, Train Acc: 98.27
# Val Loss: 0.0197, Val Acc: 73.22
# Epoch 17 of 25
# Train Loss: 0.0009, Train Acc: 99.44
# Val Loss: 0.0183, Val Acc: 73.87
# Epoch 18 of 25
# Train Loss: 0.0004, Train Acc: 99.84
# Val Loss: 0.0162, Val Acc: 75.52
# Epoch 19 of 25
# Train Loss: 0.0002, Train Acc: 99.98
# Val Loss: 0.0155, Val Acc: 76.51
# Epoch 20 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0161, Val Acc: 76.84
# Epoch 21 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0164, Val Acc: 76.51
# Epoch 22 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0150, Val Acc: 76.95
# Epoch 23 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0158, Val Acc: 76.73
# Epoch 24 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0156, Val Acc: 76.40
# Epoch 25 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0154, Val Acc: 75.96
# 4.154892408847809 minutes
# Accuracy of the network on test images: 77.614 %

# %%
model = resnet18(pretrained=False, activation='gelu').to(device)
train(model, trainloader, valloader)
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# dilation [False, False, False]
# stride 1
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Epoch 1 of 25
# Train Loss: 0.0558, Train Acc: 25.36
# Val Loss: 0.0566, Val Acc: 29.97
# Epoch 2 of 25
# Train Loss: 0.0474, Train Acc: 33.69
# Val Loss: 0.0471, Val Acc: 37.76
# Epoch 3 of 25
# Train Loss: 0.0419, Train Acc: 39.47
# Val Loss: 0.0457, Val Acc: 38.86
# Epoch 4 of 25
# Train Loss: 0.0378, Train Acc: 43.88
# Val Loss: 0.0409, Val Acc: 43.36
# Epoch 5 of 25
# Train Loss: 0.0328, Train Acc: 50.54
# Val Loss: 0.0356, Val Acc: 50.27
# Epoch 6 of 25
# Train Loss: 0.0291, Train Acc: 54.47
# Val Loss: 0.0344, Val Acc: 52.36
# Epoch 7 of 25
# Train Loss: 0.0255, Train Acc: 59.74
# Val Loss: 0.0302, Val Acc: 54.88
# Epoch 8 of 25
# Train Loss: 0.0218, Train Acc: 64.78
# Val Loss: 0.0275, Val Acc: 59.28
# Epoch 9 of 25
# Train Loss: 0.0186, Train Acc: 69.70
# Val Loss: 0.0241, Val Acc: 62.79
# Epoch 10 of 25
# Train Loss: 0.0148, Train Acc: 75.91
# Val Loss: 0.0255, Val Acc: 64.00
# Epoch 11 of 25
# Train Loss: 0.0126, Train Acc: 79.09
# Val Loss: 0.0252, Val Acc: 64.54
# Epoch 12 of 25
# Train Loss: 0.0099, Train Acc: 83.81
# Val Loss: 0.0223, Val Acc: 66.30
# Epoch 13 of 25
# Train Loss: 0.0071, Train Acc: 88.31
# Val Loss: 0.0206, Val Acc: 68.50
# Epoch 14 of 25
# Train Loss: 0.0048, Train Acc: 93.41
# Val Loss: 0.0208, Val Acc: 70.14
# Epoch 15 of 25
# Train Loss: 0.0030, Train Acc: 96.59
# Val Loss: 0.0206, Val Acc: 70.91
# Epoch 16 of 25
# Train Loss: 0.0019, Train Acc: 98.19
# Val Loss: 0.0193, Val Acc: 72.56
# Epoch 17 of 25
# Train Loss: 0.0008, Train Acc: 99.56
# Val Loss: 0.0188, Val Acc: 72.56
# Epoch 18 of 25
# Train Loss: 0.0005, Train Acc: 99.77
# Val Loss: 0.0202, Val Acc: 72.67
# Epoch 19 of 25
# Train Loss: 0.0004, Train Acc: 99.77
# Val Loss: 0.0186, Val Acc: 73.87
# Epoch 20 of 25
# Train Loss: 0.0002, Train Acc: 99.93
# Val Loss: 0.0182, Val Acc: 75.63
# Epoch 21 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0178, Val Acc: 76.07
# Epoch 22 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0180, Val Acc: 76.29
# Epoch 23 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0171, Val Acc: 76.07
# Epoch 24 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0165, Val Acc: 76.73
# Epoch 25 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0174, Val Acc: 76.29
# 4.117434004942576 minutes
# Accuracy of the network on test images: 77.614 %

# %%
model = resnet18(pretrained=False, activation='gelu').to(device)
train(model, trainloader, valloader)
correct, total = test(model, testloader)
print('Accuracy of the network on test images: %0.3f %%' % (100 * correct / total))
# Out:
# dilation [False, False, False]
# stride 1
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# downsample
# stride 2
# GELU()
# GELU()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Epoch 1 of 25
# Train Loss: 0.0558, Train Acc: 24.40
# Val Loss: 0.0589, Val Acc: 24.92
# Epoch 2 of 25
# Train Loss: 0.0486, Train Acc: 31.15
# Val Loss: 0.0493, Val Acc: 34.47
# Epoch 3 of 25
# Train Loss: 0.0436, Train Acc: 37.61
# Val Loss: 0.0446, Val Acc: 37.54
# Epoch 4 of 25
# Train Loss: 0.0381, Train Acc: 43.26
# Val Loss: 0.0396, Val Acc: 44.90
# Epoch 5 of 25
# Train Loss: 0.0338, Train Acc: 48.39
# Val Loss: 0.0377, Val Acc: 45.77
# Epoch 6 of 25
# Train Loss: 0.0295, Train Acc: 54.31
# Val Loss: 0.0330, Val Acc: 52.36
# Epoch 7 of 25
# Train Loss: 0.0259, Train Acc: 59.21
# Val Loss: 0.0304, Val Acc: 55.32
# Epoch 8 of 25
# Train Loss: 0.0221, Train Acc: 64.02
# Val Loss: 0.0286, Val Acc: 58.29
# Epoch 9 of 25
# Train Loss: 0.0186, Train Acc: 69.44
# Val Loss: 0.0296, Val Acc: 56.75
# Epoch 10 of 25
# Train Loss: 0.0157, Train Acc: 74.23
# Val Loss: 0.0233, Val Acc: 64.65
# Epoch 11 of 25
# Train Loss: 0.0127, Train Acc: 78.99
# Val Loss: 0.0226, Val Acc: 65.64
# Epoch 12 of 25
# Train Loss: 0.0097, Train Acc: 83.68
# Val Loss: 0.0231, Val Acc: 65.64
# Epoch 13 of 25
# Train Loss: 0.0075, Train Acc: 87.68
# Val Loss: 0.0214, Val Acc: 66.96
# Epoch 14 of 25
# Train Loss: 0.0053, Train Acc: 91.73
# Val Loss: 0.0227, Val Acc: 67.62
# Epoch 15 of 25
# Train Loss: 0.0038, Train Acc: 94.35
# Val Loss: 0.0255, Val Acc: 64.87
# Epoch 16 of 25
# Train Loss: 0.0027, Train Acc: 96.76
# Val Loss: 0.0222, Val Acc: 69.26
# Epoch 17 of 25
# Train Loss: 0.0018, Train Acc: 97.97
# Val Loss: 0.0181, Val Acc: 73.66
# Epoch 18 of 25
# Train Loss: 0.0010, Train Acc: 99.29
# Val Loss: 0.0182, Val Acc: 73.98
# Epoch 19 of 25
# Train Loss: 0.0004, Train Acc: 99.84
# Val Loss: 0.0161, Val Acc: 75.74
# Epoch 20 of 25
# Train Loss: 0.0002, Train Acc: 99.97
# Val Loss: 0.0159, Val Acc: 77.17
# Epoch 21 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0157, Val Acc: 77.39
# Epoch 22 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0149, Val Acc: 78.27
# Epoch 23 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0154, Val Acc: 78.27
# Epoch 24 of 25
# Train Loss: 0.0001, Train Acc: 99.98
# Val Loss: 0.0152, Val Acc: 78.16
# Epoch 25 of 25
# Train Loss: 0.0001, Train Acc: 99.97
# Val Loss: 0.0153, Val Acc: 77.61
# 4.119054818153382 minutes
# Accuracy of the network on test images: 77.555 %
